# %%
import pandas as pd
from glob import glob
from tqdm import tqdm
import scipy.stats
import numpy as np
import os

# %%
metadata = pd.read_excel('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/Tables/1_Metdata_v2.1.xlsx')
requant = pd.read_excel('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/Tables/3_Requantification_v1.3.xlsx', index_col=0).reset_index(drop=True)

# %%
# Individual deduplication : keep the sample with the highest RPM from same individual
requant_indvrmdup = requant[['sn', 'vsname', 'Inferred_Individual', 'RPM']].sort_values('RPM', ascending=False).drop_duplicates(subset=['vsname', 'Inferred_Individual'], keep='first')
requant_indvrmdup
# Out:
#               sn    vsname Inferred_Individual            RPM
# 288  R2011008079  AstV-16A              BAT256  533906.839082
# 731  R2101013076   ParV-1A             BRA2271  235245.473705
# 730  R2101013052   ParV-1A             BRA2246   62463.818710
# 729  R2101012929   ParV-1A             BRA2019   45300.307156
# 506  R2007002175   CalV-2A              BAT784   42015.537360
# ..           ...       ...                 ...            ...
# 665  R2011005935   ParV-7A                UV28       0.568081
# 797  R2011005940   AstV-2A                UV33       0.561210
# 664  R2011005944   ParV-7A                UV37       0.552419
# 22   R2007002177   FlaV-8A             19BR182       0.527513
# 663  R2011005936   ParV-7A                UV29       0.526094
#
# [794 rows x 4 columns]

# %%
def vcf2dataframe(vcfpath, parse_info=False, parse_annot=False):
    '''
    读取一个vcf转换成dataframe 列与vcfheader的列一致
    '''
    if not parse_info and parse_annot:
        parse_info = True
        print('[WARNING] When parse_annot=True, parse_info will be forced set to True!')
    for line in open(vcfpath).readlines():
        if line.startswith('#CHROM'):
            vcfdfheader = line.lstrip('#').split()
            break
    vcfdf = pd.read_table(vcfpath, comment='#', header=None, names=vcfdfheader)
    if len(vcfdf)==0:
        return vcfdf
    if parse_info:
        vcfinfo = pd.DataFrame(list(vcfdf['INFO'].apply(lambda x: { pair.split('=')[0]:pair.split('=')[1] for pair in x.split(';') })))
        vcfdf = pd.concat([vcfdf, vcfinfo], axis=1)
        if parse_annot: # parse annotation from snpEff
            ann_cols = 'Allele | Annotation | Annotation_Impact | Gene_Name | Gene_ID | Feature_Type | Feature_ID | Transcript_BioType | Rank | HGVS.c | HGVS.p | cDNA.pos / cDNA.length | CDS.pos / CDS.length | AA.pos / AA.length | Distance | ERRORS / WARNINGS / INFO'.split(' | ')
            vcfann = pd.DataFrame(list(vcfdf['ANN'].apply(lambda x: x.split('|', 15))), columns = ann_cols)
            vcfdf = pd.concat([vcfdf.drop('ANN', axis=1), vcfann], axis=1)
    return vcfdf

# %% [markdown]
# Process iSNV

# %%
result = []
adpp_result = []

for filepath in tqdm(glob('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/9.2.lofreq_iSNV_annotated/*/*.ALTiSNV.vcf')):
    vsname = filepath.split('/')[-2]
    sn = filepath.split('/')[-1].split('.')[0]
    vcfdf_ann = vcf2dataframe(filepath, parse_info=True, parse_annot=True)
    posnum = len(vcfdf_ann)
    if not posnum: # Skip empty file
        continue
    vcfdf_ann = vcfdf_ann[vcfdf_ann['iSNV']=='ALT']
    vcfdf_ann['ADPP'] = vcfdf_ann['DP4'].apply(lambda x: int(x.split(',')[2]) + int(x.split(',')[3])) / vcfdf_ann['DP'].astype(int)   # ADPP: Allele DP Percentage
    altposnum = len(vcfdf_ann)
    synonymous_vcfdf = vcfdf_ann[vcfdf_ann['Annotation']=='synonymous_variant']
    synonymous_meandp = synonymous_vcfdf['ADPP'].astype(float).mean()
    missense_vcfdf = vcfdf_ann[vcfdf_ann['Annotation']=='missense_variant']
    missense_meandp = missense_vcfdf['ADPP'].astype(float).mean()
    vcfdf_ann['CHROM'] = vsname
    vcfdf_ann['SN'] = sn
    
    adpp_result.append(vcfdf_ann[['SN','CHROM', 'POS', 'REF', 'ALT', 'ADPP', 'Annotation']])
    result.append([vsname, sn, posnum, altposnum, len(synonymous_vcfdf), synonymous_meandp, len(missense_vcfdf), missense_meandp])
# Out:
# 100%|██████████| 222/222 [00:04<00:00, 54.48it/s]

# %%
allsite_isnvdp = pd.concat(adpp_result) # table with every single iSNV POS info 
allsite_isnvdp
# Out:
#              SN      CHROM   POS REF ALT      ADPP          Annotation
# 0   R2011005870  PicoV-24A  4328   C   T  0.064286    missense_variant
# 1   R2011005870  PicoV-24A  5889   T   C  0.080645  synonymous_variant
# 0   R2011005891  PicoV-24A   660   A   C  0.101449  synonymous_variant
# 1   R2011005891  PicoV-24A  4587   T   C  0.304878  synonymous_variant
# 2   R2011005891  PicoV-24A  5448   T   C  0.122642  synonymous_variant
# ..          ...        ...   ...  ..  ..       ...                 ...
# 10  R2101012916      CV-6A  1399   A   G  0.427350    missense_variant
# 11  R2101012916      CV-6A  1405   A   T  0.356436    missense_variant
# 19  R2101012916      CV-6A  1814   T   C  0.340659  synonymous_variant
# 0   R2101012909      CV-6A  1387   C   A  0.160987    missense_variant
# 1   R2101012909      CV-6A  1387   C   T  0.056404    missense_variant
#
# [19039 rows x 7 columns]

# %%
allsite_isnvdp
# Out:
#              SN      CHROM   POS REF ALT      ADPP          Annotation
# 0   R2011005870  PicoV-24A  4328   C   T  0.064286    missense_variant
# 1   R2011005870  PicoV-24A  5889   T   C  0.080645  synonymous_variant
# 0   R2011005891  PicoV-24A   660   A   C  0.101449  synonymous_variant
# 1   R2011005891  PicoV-24A  4587   T   C  0.304878  synonymous_variant
# 2   R2011005891  PicoV-24A  5448   T   C  0.122642  synonymous_variant
# ..          ...        ...   ...  ..  ..       ...                 ...
# 10  R2101012916      CV-6A  1399   A   G  0.427350    missense_variant
# 11  R2101012916      CV-6A  1405   A   T  0.356436    missense_variant
# 19  R2101012916      CV-6A  1814   T   C  0.340659  synonymous_variant
# 0   R2101012909      CV-6A  1387   C   A  0.160987    missense_variant
# 1   R2101012909      CV-6A  1387   C   T  0.056404    missense_variant
#
# [19039 rows x 7 columns]

# %%
allsite_isnvdp = allsite_isnvdp.merge(requant_indvrmdup[['sn', 'vsname']], left_on=['SN', 'CHROM'], right_on=['sn', 'vsname'], how='inner')
allsite_isnvdp.to_excel('iSNV_full_perPOS_annotated.xlsx', index=False)

# %%
# Unfiltered iSNV num stat
allsite_isnvdp[['CHROM', 'POS']].drop_duplicates().groupby('CHROM').count().sort_values(by='POS')
# Out:
#             POS
# CHROM
# HerpV-4A      1
# CalV-21A      1
# PicoV-17B     1
# CalV-5A       1
# ParV-11A      1
# ...         ...
# ParV-1A     188
# PV-12A      240
# CalV-15A    299
# CoV-3A      824
# HerpV-2A   8408
#
# [64 rows x 1 columns]

# %%
allsite_isnvdp_missense = allsite_isnvdp[allsite_isnvdp['Annotation']=='missense_variant']
allsite_isnvdp_missense
# Out:
#                 SN      CHROM   POS REF ALT      ADPP        Annotation  \
# 0      R2011005870  PicoV-24A  4328   C   T  0.064286  missense_variant
# 5      R2011005891  PicoV-24A  5457   G   T  0.264151  missense_variant
# 6      R2011005891  PicoV-24A  6197   G   T  0.125000  missense_variant
# 28     R2011008083     CV-12A  1171   T   A  0.219643  missense_variant
# 29     R2011008083     CV-12A  1186   A   T  0.244737  missense_variant
# ...            ...        ...   ...  ..  ..       ...               ...
# 18915  R2101012916      CV-6A  1208   C   A  0.164087  missense_variant
# 18916  R2101012916      CV-6A  1399   A   G  0.427350  missense_variant
# 18917  R2101012916      CV-6A  1405   A   T  0.356436  missense_variant
# 18919  R2101012909      CV-6A  1387   C   A  0.160987  missense_variant
# 18920  R2101012909      CV-6A  1387   C   T  0.056404  missense_variant
#
#                 sn     vsname
# 0      R2011005870  PicoV-24A
# 5      R2011005891  PicoV-24A
# 6      R2011005891  PicoV-24A
# 28     R2011008083     CV-12A
# 29     R2011008083     CV-12A
# ...            ...        ...
# 18915  R2101012916      CV-6A
# 18916  R2101012916      CV-6A
# 18917  R2101012916      CV-6A
# 18919  R2101012909      CV-6A
# 18920  R2101012909      CV-6A
#
# [4526 rows x 9 columns]

# %%
allsite_isnvdp_synonymous = allsite_isnvdp[allsite_isnvdp['Annotation']=='synonymous_variant']
allsite_isnvdp_synonymous
# Out:
#                 SN      CHROM    POS REF ALT      ADPP          Annotation  \
# 1      R2011005870  PicoV-24A   5889   T   C  0.080645  synonymous_variant
# 2      R2011005891  PicoV-24A    660   A   C  0.101449  synonymous_variant
# 3      R2011005891  PicoV-24A   4587   T   C  0.304878  synonymous_variant
# 4      R2011005891  PicoV-24A   5448   T   C  0.122642  synonymous_variant
# 7      R2101013357   CalV-11A   3405   C   T  0.145695  synonymous_variant
# ...            ...        ...    ...  ..  ..       ...                 ...
# 18906  R2101013376     CoV-4B   1368   T   C  0.482143  synonymous_variant
# 18907  R2101013376     CoV-4B  24498   C   T  0.097087  synonymous_variant
# 18912  R2101012916      CV-6A    208   G   T  0.396947  synonymous_variant
# 18913  R2101012916      CV-6A    379   A   G  0.180645  synonymous_variant
# 18918  R2101012916      CV-6A   1814   T   C  0.340659  synonymous_variant
#
#                 sn     vsname
# 1      R2011005870  PicoV-24A
# 2      R2011005891  PicoV-24A
# 3      R2011005891  PicoV-24A
# 4      R2011005891  PicoV-24A
# 7      R2101013357   CalV-11A
# ...            ...        ...
# 18906  R2101013376     CoV-4B
# 18907  R2101013376     CoV-4B
# 18912  R2101012916      CV-6A
# 18913  R2101012916      CV-6A
# 18918  R2101012916      CV-6A
#
# [12188 rows x 9 columns]

# %%
isnv_stat = pd.DataFrame(result, columns=['vsname', 'sn', 'num_iSNV', 'num_ALTiSNV', 'synonymous_varnum', 'synonymous_mean', 'nonsynonymous_varnum', 'nonsynonymous_mean']) # 
isnv_stat
# Out:
#         vsname           sn  num_iSNV  num_ALTiSNV  synonymous_varnum  \
# 0    PicoV-24A  R2011005870         2            2                  1
# 1    PicoV-24A  R2011005891         5            5                  3
# 2     CalV-11A  R2101013357         3            3                  3
# 3     CalV-11A  R2101013362         7            7                  7
# 4     CalV-11A  R2101013359         6            5                  5
# ..         ...          ...       ...          ...                ...
# 217   ParaV-7A  R2012012418         1            1                  0
# 218   ParaV-7A  R2012012434         2            2                  0
# 219   AstV-14B  R2012012518         1            1                  0
# 220      CV-6A  R2101012916        24            7                  3
# 221      CV-6A  R2101012909         2            2                  0
#
#      synonymous_mean  nonsynonymous_varnum  nonsynonymous_mean
# 0           0.080645                     1            0.064286
# 1           0.176323                     2            0.194575
# 2           0.105905                     0                 NaN
# 3           0.187506                     0                 NaN
# 4           0.398594                     0                 NaN
# ..               ...                   ...                 ...
# 217              NaN                     1            0.115385
# 218              NaN                     2            0.072944
# 219              NaN                     1            0.307692
# 220         0.306084                     4            0.316236
# 221              NaN                     2            0.108696
#
# [222 rows x 8 columns]

# %%
isnv_stat['num_iSNV'].sum()
# Out:
# 32631

# %%
isnv_stat.to_excel('iSNV_variantDPstat.xlsx', index=None)

# %%
isnv_stat.dropna()
# Out:
#         vsname  num_varsite  samplenum  synonymous_varnum  synonymous_mean  \
# 0    PicoV-24A  R2011005870          2                  1         0.080645
# 1    PicoV-24A  R2011005891          5                  3         0.176323
# 8     PicoV-4A  R2007002137         20                 16         0.112079
# 9     PicoV-4A  R2011008081          6                  4         0.245958
# 11    HerpV-2A  R2011008212         89                 39         0.291837
# ..         ...          ...        ...                ...              ...
# 212    ReoV-2B  R2012012471          2                  1         0.259259
# 213    PolV-5A  R2011005797        147                 83         0.245467
# 214     CoV-4B  R2101013364         15                  9         0.305226
# 215     CoV-4B  R2101013369          3                  1         0.060606
# 220      CV-6A  R2101012916         24                  3         0.306084
#
#      nonsynonymous_varnum  nonsynonymous_mean
# 0                       1            0.064286
# 1                       2            0.194575
# 8                       1            0.129496
# 9                       1            0.170846
# 11                     15            0.317799
# ..                    ...                 ...
# 212                     1            0.070175
# 213                    37            0.229185
# 214                     4            0.144638
# 215                     2            0.150083
# 220                     4            0.316236
#
# [128 rows x 7 columns]

# %%
scipy.stats.wilcoxon(list(isnv_stat.dropna()['synonymous_mean']), list(isnv_stat.dropna()['nonsynonymous_mean']))
# Out:
# WilcoxonResult(statistic=3074.0, pvalue=0.012190893096740658)

# %%
scipy.stats.mannwhitneyu(list(allsite_isnvdp_synonymous['ADPP']), list(allsite_isnvdp_missense['ADPP']))
# Out:
# MannwhitneyuResult(statistic=27783595.5, pvalue=0.5248744974058455)

# %% [markdown]
# Remove Coinfection

# %%
vsnamelist = list(map(lambda x: x.split('.')[0], os.listdir('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/refiltering_test/filtered_annotated')))

# %%
def parsing_sitepos(vcfpath):
    varpos = []
    for line in open(vcfpath).readlines():
        if line.startswith('#'):
            continue
        else:
            chrom, pos, id, ref, alt, *_ = line.strip().split()
            varpos.append(int(pos))
    return varpos

# %%
def compare_sites(isnvdict, fbvcfdict, coinfect_threshold=3):
    '''
    比较每个样本的isnv和csnv
    '''
    output_list = []
    for isnvsn, isnvsites in isnvdict.items():
        for csnvsn, csnvsites in fbvcfdict.items():
            isec_sites = set(isnvsites) & set(csnvsites)
            if len(isec_sites) >= coinfect_threshold:
                output_list.append([isnvsn, csnvsn, len(isec_sites)])
    outputdf = pd.DataFrame(output_list, columns=['iSNV_sn', 'cSNV_sn', 'isec_sites'])
    return outputdf

# %%
coinfect_resultlist = []
fbvcf_stat = []

for vsname in vsnamelist:
    fbvcfpath = '/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/refiltering_test/filtered_annotated/{vsname}.snpeff.vcf'.format(vsname=vsname)
    if not os.path.exists('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/9.2.lofreq_iSNV_annotated/{vsname}'.format(vsname=vsname)):
        continue
    fbvcfdf = vcf2dataframe(fbvcfpath)
    requantsn = set(requant_indvrmdup.loc[requant_indvrmdup['vsname']==vsname, 'sn'])
    fbsnlist = set(fbvcfdf.columns[9:])
    kept_fbsnlist = requantsn & fbsnlist
    fbvcf_stat.append([vsname, len(kept_fbsnlist), len(fbvcfdf)])
    # convert cSNV for every single individual (1:...) into dictionary, format as {sn1:[POS1,POS2,POS3....],sn2:[...]}
    fbvcfvardict = { sn:list(fbvcfdf.loc[fbvcfdf[sn].apply(lambda x: x.startswith('1:')), 'POS']) for sn in kept_fbsnlist }  
    lofreqvcflist = glob('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/9.2.lofreq_iSNV_annotated/{vsname}/*.vcf'.format(vsname=vsname))
    # convert iSNV called by lofreq into dictionary, using the same format as cSNV
    isnvdict = { filepath.split('/')[-1].split('.')[0]:list(vcf2dataframe(filepath)['POS']) for filepath in lofreqvcflist }
    compare_df = compare_sites(isnvdict, fbvcfvardict, coinfect_threshold=3) # compare variation sites between iSNV and cSNV，at least 3 variant at same position will considered as coinfection event
    compare_df['vsname'] = vsname
    coinfect_resultlist.append(compare_df)
    
coinfect_resultdf = pd.concat(coinfect_resultlist)

# %%
fbvcf_statdf = pd.DataFrame(fbvcf_stat, columns=['vsname', 'num_sample', 'num_sites'])
fbvcf_statdf_filtered = fbvcf_statdf[(fbvcf_statdf['num_sample']>4) & (fbvcf_statdf['num_sites']>20)].copy()
fbvcf_statdf_filtered['vsname'].to_csv('ld_kept_vsname.list', sep='\t')

# %%
coinfect_resultdf_dropself = coinfect_resultdf[coinfect_resultdf['iSNV_sn']!=coinfect_resultdf['cSNV_sn']].copy()   # 去除同一个样本发现的iSNV和cSNV共感染组合
coinfect_resultdf_dropself
# Out:
#         iSNV_sn      cSNV_sn isec_sites     vsname
# 0   R2011005922  R2101013343          4  PicoV-10A
# 1   R2011005922  R2101013353          5  PicoV-10A
# 2   R2011005922  R2011005932          3  PicoV-10A
# 3   R2011005922  R2011005931          3  PicoV-10A
# 0   R2011005939  R2101013342         10    AstV-2A
# ..          ...          ...        ...        ...
# 1   R2011005924  R2011005936          4      CV-8B
# 0   R2011008097  R2011008078          3     AdV-2A
# 2   R2011008097  R2011008080          8     AdV-2A
# 0   R2012012472  R2012012462          4    ParV-2A
# 1   R2012012457  R2012012462          8    ParV-2A
#
# [204 rows x 4 columns]

# %%
coinfect_list = list(coinfect_resultdf_dropself['vsname'] + ' ' + coinfect_resultdf_dropself['iSNV_sn'])

# %%
coinfect_list
# Out:
# ['PicoV-10A R2011005922',
#  'PicoV-10A R2011005922',
#  'PicoV-10A R2011005922',
#  'PicoV-10A R2011005922',
#  'AstV-2A R2011005939',
#  'AstV-2A R2011005939',
#  'ParV-26A R2101013380',
#  'ParV-26A R2101013380',
#  'ParV-26A R2101013381',
#  'ParV-26A R2101013381',
#  'ParV-26A R2101013377',
#  'ParV-26A R2101013377',
#  'CV-14A R2101013369',
#  'CV-14A R2101013369',
#  'CV-14A R2101013369',
#  'CV-14A R2101013376',
#  'CV-14A R2101013376',
#  'CV-14A R2101013376',
#  'CV-14A R2101013376',
#  'CV-14A R2101013365',
#  'CV-14A R2101013365',
#  'AstV-15A R2012012506',
#  'AstV-15A R2012012506',
#  'HanV-1A R2101013353',
#  'HanV-1A R2101013353',
#  'HanV-1A R2101013343',
#  'HanV-1A R2101013343',
#  'CV-3A R2101013365',
#  'CV-3A R2101013365',
#  'CV-3A R2101013365',
#  'CalV-13A R2101013353',
#  'CalV-13A R2101013353',
#  'CalV-13A R2101013353',
#  'CalV-13A R2101013353',
#  'CalV-13A R2101013353',
#  'CalV-13A R2103020334',
#  'ParV-21A R2101013401',
#  'ParV-21A R2101013401',
#  'ParV-21A R2101013401',
#  'PicoV-17A R2012012566',
#  'PicoV-17A R2012012566',
#  'PicoV-17A R2012012566',
#  'PicoV-17A R2012012566',
#  'PicoV-17A R2012012566',
#  'PicoV-17A R2012012566',
#  'CalV-15A R2012012552',
#  'CalV-15A R2012012552',
#  'CalV-15A R2012012552',
#  'HerpV-2A R2011008212',
#  'HerpV-2A R2011008212',
#  'HerpV-2A R2011008212',
#  'HerpV-2A R2011008212',
#  'HerpV-2A R2011008212',
#  'HerpV-2A R2011008212',
#  'HerpV-2A R2011008212',
#  'HerpV-2A R2011008212',
#  'HerpV-2A R2101013266',
#  'HerpV-2A R2101013266',
#  'HerpV-2A R2101013266',
#  'HerpV-2A R2101013266',
#  'HerpV-2A R2101013266',
#  'HerpV-2A R2101013266',
#  'HerpV-2A R2101013266',
#  'HerpV-2A R2101013266',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008225',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008211',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008219',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008210',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008220',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008223',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'HerpV-2A R2011008221',
#  'CoV-8A R2012012520',
#  'CoV-8A R2012012520',
#  'CoV-8A R2012012520',
#  'CoV-8A R2012012521',
#  'CoV-8A R2012012521',
#  'CoV-8A R2012012521',
#  'CoV-8A R2012012521',
#  'CoV-3A R2011008248',
#  'CoV-3A R2011008248',
#  'CoV-3A R2011008248',
#  'CoV-3A R2011008248',
#  'CoV-3A R2011008248',
#  'CoV-3A R2011008248',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2011008077',
#  'CoV-3A R2101013343',
#  'CoV-3A R2101013343',
#  'CoV-3A R2101013343',
#  'CoV-3A R2101013343',
#  'CoV-3A R2101013343',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2007002129',
#  'CoV-3A R2011008165',
#  'CoV-3A R2011008165',
#  'CoV-3A R2011008165',
#  'CoV-3A R2011008165',
#  'CoV-3A R2011008165',
#  'CoV-3A R2011008165',
#  'CoV-3A R2011008165',
#  'CoV-3A R2011008165',
#  'CoV-3A R2011008165',
#  'AstV-9A R2101013376',
#  'ReoV-3A R2011008092',
#  'ReoV-3A R2011008092',
#  'PicoV-6A R2011008205',
#  'PicoV-6A R2011008205',
#  'PicoV-6A R2011008205',
#  'PicoV-6A R2011008205',
#  'PicoV-6A R2011008205',
#  'PicoV-6A R2011008205',
#  'PicoV-6A R2011008205',
#  'PicoV-6A R2012012568',
#  'PicoV-6A R2011008176',
#  'PicoV-6A R2011008176',
#  'ParV-5A R2011008088',
#  'CV-8B R2011005950',
#  'CV-8B R2011005924',
#  'AdV-2A R2011008097',
#  'AdV-2A R2011008097',
#  'ParV-2A R2012012472',
#  'ParV-2A R2012012457']

# %% [markdown]
# 统计iSNV数量

# %%
kept_pair = list(requant_indvrmdup['vsname'] + ' ' + requant_indvrmdup['sn'])

# %%
result = []
adpp_result = []
coinfection_result = []

for filepath in tqdm(glob('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/9.2.lofreq_iSNV_annotated/*/*.ALTiSNV.vcf')):
    vsname = filepath.split('/')[-2]
    sn = filepath.split('/')[-1].split('.')[0]
    if not vsname + ' ' + sn in kept_pair:
        print(vsname + ' ' + sn + ' removed(indv-dedup)!') 
        continue 
    if vsname + ' ' + sn in coinfect_list:   # 如果该vs-sn pair出现在共感染列表或未出现在保留的pair中，则去除
        print(vsname + ' ' + sn + ' removed!')
        coinfection_result.append([vsname, sn, True])
        continue
    else:
        coinfection_result.append([vsname, sn, False])
    
    vcfdf_ann = vcf2dataframe(filepath, parse_info=True, parse_annot=True)
    posnum = len(vcfdf_ann)
    if not posnum:
        continue
    vcfdf_ann = vcfdf_ann[vcfdf_ann['iSNV']=='ALT']
    vcfdf_ann['ADPP'] = vcfdf_ann['DP4'].apply(lambda x: int(x.split(',')[2]) + int(x.split(',')[3])) / vcfdf_ann['DP'].astype(int)
    
    altposnum = len(vcfdf_ann)
    
    synonymous_vcfdf = vcfdf_ann[vcfdf_ann['Annotation']=='synonymous_variant']
    synonymous_meandp = synonymous_vcfdf['ADPP'].astype(float).mean()
    missense_vcfdf = vcfdf_ann[vcfdf_ann['Annotation']=='missense_variant']
    missense_meandp = missense_vcfdf['ADPP'].astype(float).mean()
    vcfdf_ann['CHROM'] = vsname
    vcfdf_ann['SN'] = sn
    adpp_result.append(vcfdf_ann[['SN','CHROM', 'POS', 'REF', 'ALT', 'ADPP', 'Annotation']])
    
    result.append([vsname, sn, posnum, altposnum, len(synonymous_vcfdf), synonymous_meandp, len(missense_vcfdf), missense_meandp])
# Out:
#  11%|█▏        | 25/222 [00:00<00:01, 128.74it/s]
# HerpV-2A R2011008212 removed!
# HerpV-2A R2101013266 removed!
# HerpV-2A R2011008225 removed!
# HerpV-2A R2011008211 removed!
# HerpV-2A R2011008219 removed!
# HerpV-2A R2011008210 removed!
# HerpV-2A R2011008220 removed!
# HerpV-2A R2011008223 removed!
# HerpV-2A R2011008221 removed!
# AdV-2A R2011008097 removed!
#  27%|██▋       | 60/222 [00:00<00:01, 86.79it/s]
# CV-14A R2101013369 removed!
# CV-14A R2101013376 removed!
# CV-14A R2101013365 removed!
#  36%|███▌      | 79/222 [00:00<00:01, 87.94it/s]
# AstV-9A R2101013376 removed!
# CV-3A R2101013365 removed!
# ReoV-3A R2011008092 removed!
# AstV-15A R2012012506 removed!
#  40%|████      | 89/222 [00:00<00:01, 88.48it/s]
# HanV-1A R2101013353 removed!
# HanV-1A R2101013343 removed!
#  50%|█████     | 111/222 [00:01<00:01, 95.96it/s]
# CoV-3A R2011008248 removed!
# CoV-3A R2011008077 removed!
# CoV-3A R2101013343 removed!
# CoV-3A R2007002129 removed!
# CoV-3A R2011008165 removed!
# CV-4A R2101013092 removed(indv-dedup)!
# PicoV-10A R2011005922 removed!
# ParV-21A R2101013401 removed!
# PicoV-17A R2012012566 removed!
#  64%|██████▍   | 142/222 [00:01<00:00, 95.38it/s]
# CV-8B R2011005950 removed!
# CV-8B R2011005924 removed!
# PicoV-6A R2011008205 removed!
# PicoV-6A R2012012568 removed!
# PicoV-6A R2011008176 removed!
# ParV-2A R2012012472 removed!
#  74%|███████▍  | 165/222 [00:01<00:00, 101.39it/s]
# ParV-2A R2012012457 removed!
# CalV-13A R2101013353 removed!
# CalV-13A R2103020334 removed!
# CalV-15A R2012012552 removed!
# ParV-5A R2011008088 removed!
# AstV-2A R2011005939 removed!
# CoV-8A R2012012520 removed!
#  84%|████████▍ | 187/222 [00:01<00:00, 90.70it/s]
# CoV-8A R2012012521 removed!
# ParV-26A R2101013380 removed!
# ParV-26A R2101013381 removed!
# ParV-26A R2101013377 removed!
#  94%|█████████▎| 208/222 [00:02<00:00, 84.13it/s]
# ParV-1A R2101013032 removed(indv-dedup)!
# 100%|██████████| 222/222 [00:02<00:00, 90.38it/s]

# %%
coinfdf = pd.DataFrame(coinfection_result, columns=['vsname', 'sn', 'coinfection']).merge(requantdf[['vsname', 'sn', 'meandepth', 'coverage']], on=['vsname', 'sn'], how='left')
coinfdf = coinfdf[(coinfdf['meandepth']>50)]
coinfdf.to_csv('CoInfection_stat.csv', index=False)

# %%
set(coinfdf[coinfdf['coinfection']]['vsname'])
# Out:
# {'AdV-2A',
#  'AstV-15A',
#  'AstV-2A',
#  'AstV-9A',
#  'CV-14A',
#  'CV-3A',
#  'CV-8B',
#  'CalV-13A',
#  'CalV-15A',
#  'CoV-3A',
#  'HanV-1A',
#  'HerpV-2A',
#  'ParV-26A',
#  'ParV-2A',
#  'ParV-5A',
#  'PicoV-17A',
#  'PicoV-6A',
#  'ReoV-3A'}

# %%
isnv_stat = pd.DataFrame(result, columns=['vsname', 'sn', 'num_iSNV', 'num_ALTiSNV', 'synonymous_ALTiSNV', 'synonymous_meanDP', 'nonsynonymous_ALTiSNV', 'nonsynonymous_meanDP'])
isnv_stat
# Out:
#         vsname           sn  num_iSNV  num_ALTiSNV  synonymous_ALTiSNV  \
# 0    PicoV-24A  R2011005870         2            2                   1
# 1    PicoV-24A  R2011005891         5            5                   3
# 2     CalV-11A  R2101013357         3            3                   3
# 3     CalV-11A  R2101013362         7            7                   7
# 4     CalV-11A  R2101013359         6            5                   5
# ..         ...          ...       ...          ...                 ...
# 171   ParaV-7A  R2012012418         1            1                   0
# 172   ParaV-7A  R2012012434         2            2                   0
# 173   AstV-14B  R2012012518         1            1                   0
# 174      CV-6A  R2101012916        24            7                   3
# 175      CV-6A  R2101012909         2            2                   0
#
#      synonymous_meanDP  nonsynonymous_ALTiSNV  nonsynonymous_meanDP
# 0             0.080645                      1              0.064286
# 1             0.176323                      2              0.194575
# 2             0.105905                      0                   NaN
# 3             0.187506                      0                   NaN
# 4             0.398594                      0                   NaN
# ..                 ...                    ...                   ...
# 171                NaN                      1              0.115385
# 172                NaN                      2              0.072944
# 173                NaN                      1              0.307692
# 174           0.306084                      4              0.316236
# 175                NaN                      2              0.108696
#
# [176 rows x 8 columns]

# %%
requantdf = pd.read_excel('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/VirusQuantification/requant_outjoin_v2.2.xlsx')
requantdf
# Out:
#      Unnamed: 0           sn                   rname  startpos  endpos  \
# 0             0  R2007002118    19BR163KID-k99_18062         1   19279
# 1             1  R2007002122  FlaV-1B-Scaffold_pilon         1    9054
# 2             2  R2007002122    19BR184KID-k119_9215         1   18012
# 3             3  R2007002122     19BR181KID-k99_6171         1   17571
# 4             4  R2007002128     19BR181KID-k99_6171         1   17571
# ..          ...          ...                     ...       ...     ...
# 867         867  R2103020503      BFS094-k141_118387         1    2403
# 868         868  R2103020506      BFS126-k141_247049         1   28849
# 869         869  R2103020507      BFS126-k141_247049         1   28849
# 870         870  R2103020508       BFS128-k141_50115         1    2050
# 871         871  R2103020509      BFS126-k141_247049         1   28849
#
#      numreads  covbases  coverage    meandepth  meanbaseq  ...  80ani_clus  \
# 0         152      7889   40.9202     0.934333       35.8  ...     ParaV-1
# 1       11307      9054  100.0000   122.025000       34.1  ...      FlaV-1
# 2      146760     18012  100.0000   796.678000       34.1  ...     ParaV-3
# 3         297     11149   63.4511     1.554720       32.7  ...     ParaV-5
# 4         262     11392   64.8341     1.414090       31.0  ...     ParaV-5
# ..        ...       ...       ...          ...        ...  ...         ...
# 867       568      2403  100.0000    34.259300       35.5  ...      ReoV-6
# 868    352123     28849  100.0000  1794.840000       34.7  ...       CoV-4
# 869    120187     28768   99.7192   607.407000       35.2  ...       CoV-4
# 870       564      2050  100.0000    40.319000       34.5  ...       PV-13
# 871      3245     13288   46.0605    16.119300       34.9  ...       CoV-4
#
#      95ani_clus   Sample_ID  numreads_m  cleandata_gb           RPM  \
# 0      ParaV-1A  19BR163KID  176.314638     23.352879      0.862095
# 1       FlaV-1B  19BR184KID   58.882182      5.834255    192.027531
# 2      ParaV-3A  19BR184KID   58.882182      5.834255   2492.434808
# 3      ParaV-5A  19BR184KID   58.882182      5.834255      5.043971
# 4      ParaV-5A      2260LU   61.835300      6.124275      4.237062
# ..          ...         ...         ...           ...           ...
# 867     ReoV-6A      BFS094   25.904896      3.865663     21.926357
# 868      CoV-4D      BFS126   36.265582      5.417530   9709.564292
# 869      CoV-4D      BFS127    7.787306      1.161016  15433.707113
# 870      PV-13A      BFS128   13.945758      2.072339     40.442405
# 871      CoV-4D      BFS132   21.733640      3.235407    149.307709
#
#      Inferred_Individual                    Final_species        Sample_Type  \
# 0                19BR163               Otomys angoniensis      Kidney_tissue
# 1                19BR184        Lophuromys flavopunctatus      Kidney_tissue
# 2                19BR184        Lophuromys flavopunctatus      Kidney_tissue
# 3                19BR184        Lophuromys flavopunctatus      Kidney_tissue
# 4                 2260LU                         Mus bufo        Lung_tissue
# ..                   ...                              ...                ...
# 867               BFS094                   Triaenops afer  Single_fecal_swab
# 868               BFS126  Miniopterus sp. clade 5 TD-2020  Single_fecal_swab
# 869               BFS127  Miniopterus sp. clade 5 TD-2020  Single_fecal_swab
# 870               BFS128  Miniopterus sp. clade 5 TD-2020  Single_fecal_swab
# 871               BFS132  Miniopterus sp. clade 5 TD-2020  Single_fecal_swab
#
#     Host_Category
# 0             Rat
# 1             Rat
# 2             Rat
# 3             Rat
# 4             Rat
# ..            ...
# 867           Bat
# 868           Bat
# 869           Bat
# 870           Bat
# 871           Bat
#
# [872 rows x 29 columns]

# %%
requantdf[(requantdf['meandepth']>50) & (requantdf['vsname'] +' ' + requantdf['sn']).isin(coinfect_list)]['vfamily'].value_counts()
# Out:
# vfamily
# Circoviridae      6
# Parvoviridae      6
# Herpesviridae     6
# Astroviridae      3
# Picornaviridae    3
# Caliciviridae     3
# Coronaviridae     2
# Hantaviridae      2
# Reoviridae        1
# Adenoviridae      1
# Name: count, dtype: int64

# %%
isnv_stat_mergedp = isnv_stat.merge(requantdf[['vsname', 'sn', 'meandepth', 'coverage']], on=['vsname', 'sn'], how='left')

# %%
isnv_stat_filtdp = isnv_stat_mergedp[isnv_stat_mergedp['meandepth']>=50]
isnv_stat_filtdp
# Out:
#        vsname           sn  num_iSNV  num_ALTiSNV  synonymous_ALTiSNV  \
# 2    CalV-11A  R2101013357         3            3                   3
# 3    CalV-11A  R2101013362         7            7                   7
# 5      CV-12A  R2011008079         5            5                   1
# 6      CV-12A  R2011008085         3            1                   0
# 7      CV-12A  R2011008083        16            8                   0
# ..        ...          ...       ...          ...                 ...
# 207   ParV-1A  R2101013077        86           50                   1
# 208   ReoV-2B  R2012012467        66           45                  29
# 209   ReoV-2B  R2012012465         5            5                   3
# 218     CV-6A  R2101012916        24            7                   3
# 219     CV-6A  R2101012909         2            2                   0
#
#      synonymous_meanDP  nonsynonymous_ALTiSNV  nonsynonymous_meanDP  \
# 2             0.105905                      0                   NaN
# 3             0.187506                      0                   NaN
# 5             0.076060                      0                   NaN
# 6                  NaN                      0                   NaN
# 7                  NaN                      2              0.232190
# ..                 ...                    ...                   ...
# 207           0.100070                      0                   NaN
# 208           0.305499                      1              0.076923
# 209           0.064791                      2              0.070476
# 218           0.306084                      4              0.316236
# 219                NaN                      2              0.108696
#
#      meandepth  coverage
# 2     322.8590  100.0000
# 3     628.6070  100.0000
# 5     813.1420  100.0000
# 6      52.4100   74.5821
# 7     443.6190   95.9685
# ..         ...       ...
# 207  1829.6200   86.7643
# 208    74.3356   98.1026
# 209   282.4040  100.0000
# 218   171.2540  100.0000
# 219  1086.8400  100.0000
#
# [133 rows x 10 columns]

# %%
isnv_stat_filtdp.merge(allsite_isnvdp, left_on=['vsname','sn'], right_on=['CHROM','SN'], how='left').to_excel('iSNV_DPperPOS_filtered.xlsx', index=False)

# %%
isnv_stat_filtdp.to_excel('iSNV_DPstat_filtCoInf_filtDP_indv.xlsx', index=False)

# %%
isnv_stat_filtdp
# Out:
#        vsname           sn  num_iSNV  num_ALTiSNV  synonymous_ALTiSNV  \
# 2    CalV-11A  R2101013357         3            3                   3
# 3    CalV-11A  R2101013362         7            7                   7
# 5      CV-12A  R2011008079         5            5                   1
# 6      CV-12A  R2011008085         3            1                   0
# 7      CV-12A  R2011008083        16            8                   0
# ..        ...          ...       ...          ...                 ...
# 163   ParV-1A  R2101013077        86           50                   1
# 164   ReoV-2B  R2012012467        66           45                  29
# 165   ReoV-2B  R2012012465         5            5                   3
# 174     CV-6A  R2101012916        24            7                   3
# 175     CV-6A  R2101012909         2            2                   0
#
#      synonymous_meanDP  nonsynonymous_ALTiSNV  nonsynonymous_meanDP  \
# 2             0.105905                      0                   NaN
# 3             0.187506                      0                   NaN
# 5             0.076060                      0                   NaN
# 6                  NaN                      0                   NaN
# 7                  NaN                      2              0.232190
# ..                 ...                    ...                   ...
# 163           0.100070                      0                   NaN
# 164           0.305499                      1              0.076923
# 165           0.064791                      2              0.070476
# 174           0.306084                      4              0.316236
# 175                NaN                      2              0.108696
#
#      meandepth  coverage
# 2     322.8590  100.0000
# 3     628.6070  100.0000
# 5     813.1420  100.0000
# 6      52.4100   74.5821
# 7     443.6190   95.9685
# ..         ...       ...
# 163  1829.6200   86.7643
# 164    74.3356   98.1026
# 165   282.4040  100.0000
# 174   171.2540  100.0000
# 175  1086.8400  100.0000
#
# [100 rows x 10 columns]

# %%
statresult = []
vardirection_stat = []
for vsname, dfvsname in isnv_stat_filtdp.groupby('vsname'):
    vs_isnvsites = set()
    for sn in list(dfvsname['sn']):
        isnv_vcfdf = vcf2dataframe('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/9.2.lofreq_iSNV_annotated/{vsname}/{sn}.ALTiSNV.vcf'.format(vsname=vsname, sn=sn))
        isnv_refseqid = isnv_vcfdf.loc[0, 'CHROM']
        var_direction = { 'vsname':vsname, 'refid':isnv_refseqid, 'sn':sn, 'num_iSNV':len(isnv_vcfdf), 'A->G':0, 'G->A':0, 'T->C':0, 'C->T':0 }
        isnv_vcfdf['vardirection'] = isnv_vcfdf['REF'] + '->' + isnv_vcfdf['ALT']
        for var_record in list(isnv_vcfdf['vardirection']):
            if var_record in var_direction.keys():
                var_direction[var_record] += 1
        isnvsites = isnv_vcfdf['POS']
        vs_isnvsites = vs_isnvsites | set(isnvsites)
        vardirection_stat.append(var_direction)
    statresult.append([vsname, len(dfvsname['sn']), len(vs_isnvsites)])

# %%
vardirection_df = pd.DataFrame(vardirection_stat)
vardirection_df
# Out:
#       vsname                refid           sn  num_iSNV  A->G  G->A  T->C  \
# 0     AdV-2A           MIX-AdV-2A  R2011008078        15     6     1     0
# 1     AdV-2A           MIX-AdV-2A  R2011008080         3     0     0     0
# 2   AstV-15A  BAT1537-k141_146819  R2012012510         8     0     1     3
# 3   AstV-15A  BAT1537-k141_146819  R2012012518         5     0     1     2
# 4    AstV-9A   BAT2999-k141_16468  R2101013365         4     2     1     0
# ..       ...                  ...          ...       ...   ...   ...   ...
# 95  PicoV-8A     UGR5-k141_333212  R2103020271         5     0     0     1
# 96   PoxV-1A         OPTM-PoxV-1A  R2103020336         2     0     0     0
# 97   ReoV-2B   BAT1219-k141_71479  R2012012467        66    22    12    12
# 98   ReoV-2B   BAT1219-k141_71479  R2012012465         5     1     0     2
# 99   ReoV-3A   BAT269-k141_191601  R2007002137         5     0     1     1
#
#     C->T
# 0      1
# 1      0
# 2      3
# 3      0
# 4      1
# ..   ...
# 95     2
# 96     0
# 97    15
# 98     1
# 99     1
#
# [100 rows x 8 columns]

# %%
vardirection_df['A<->G'] = vardirection_df['A->G'] + vardirection_df['G->A'] 
vardirection_df['C<->T'] = vardirection_df['C->T'] + vardirection_df['T->C']
vardirection_df['Transitions'] = vardirection_df['A<->G'] + vardirection_df['C<->T']
vardirection_df['Transversions'] = vardirection_df['num_iSNV'] - vardirection_df['Transitions']

# %%
basenum = pd.read_table('refseq_baseperc.tsv', header=None, names=['refid', 'length', r'%A', r'%T', r'%C', r'%G', r'%GC', r'%AT'])
vardirection_mergebaseperc = vardirection_df.merge(basenum, on='refid')
for vartype in list(var_direction.keys())[-4:]:
    vardirection_mergebaseperc['normalized_{vt}'.format(vt=vartype)] = vardirection_mergebaseperc[vartype] / vardirection_mergebaseperc[r'%'+vartype[0]]

# %%
isnv_stat_all = isnv_stat_filtdp.drop('num_iSNV', axis=1).merge(vardirection_mergebaseperc, on=['vsname', 'sn'], how='left')
isnv_stat_all
# Out:
#       vsname           sn  num_ALTiSNV  synonymous_ALTiSNV  synonymous_meanDP  \
# 0   CalV-11A  R2101013357            3                   3           0.105905
# 1   CalV-11A  R2101013362            7                   7           0.187506
# 2     CV-12A  R2011008079            5                   1           0.076060
# 3     CV-12A  R2011008085            1                   0                NaN
# 4     CV-12A  R2011008083            8                   0                NaN
# ..       ...          ...          ...                 ...                ...
# 95   ParV-1A  R2101013077           50                   1           0.100070
# 96   ReoV-2B  R2012012467           45                  29           0.305499
# 97   ReoV-2B  R2012012465            5                   3           0.064791
# 98     CV-6A  R2101012916            7                   3           0.306084
# 99     CV-6A  R2101012909            2                   0                NaN
#
#     nonsynonymous_ALTiSNV  nonsynonymous_meanDP  meandepth  coverage  \
# 0                       0                   NaN   322.8590  100.0000
# 1                       0                   NaN   628.6070  100.0000
# 2                       0                   NaN   813.1420  100.0000
# 3                       0                   NaN    52.4100   74.5821
# 4                       2              0.232190   443.6190   95.9685
# ..                    ...                   ...        ...       ...
# 95                      0                   NaN  1829.6200   86.7643
# 96                      1              0.076923    74.3356   98.1026
# 97                      2              0.070476   282.4040  100.0000
# 98                      4              0.316236   171.2540  100.0000
# 99                      2              0.108696  1086.8400  100.0000
#
#                      refid  ...     %A     %T     %C     %G    %GC    %AT  \
# 0      BAT2985-k141_116061  ...  24.57  27.35  24.59  23.49  48.09  51.91
# 1      BAT2985-k141_116061  ...  24.57  27.35  24.59  23.49  48.09  51.91
# 2        BAT256-k141_32339  ...  26.35  30.38  22.57  20.70  43.26  56.74
# 3        BAT256-k141_32339  ...  26.35  30.38  22.57  20.70  43.26  56.74
# 4        BAT256-k141_32339  ...  26.35  30.38  22.57  20.70  43.26  56.74
# ..                     ...  ...    ...    ...    ...    ...    ...    ...
# 95   RNALIV2019-k141_21519  ...  35.29  25.67  18.26  20.79  39.04  60.96
# 96      BAT1219-k141_71479  ...  29.23  29.59  15.44  25.74  41.18  58.82
# 97      BAT1219-k141_71479  ...  29.23  29.59  15.44  25.74  41.18  58.82
# 98  RNAKID1997-k141_187969  ...  23.81  20.37  29.16  26.66  55.83  44.17
# 99  RNAKID1997-k141_187969  ...  23.81  20.37  29.16  26.66  55.83  44.17
#
#     normalized_A->G  normalized_G->A  normalized_T->C  normalized_C->T
# 0          0.000000         0.000000         0.000000         0.122001
# 1          0.081400         0.042571         0.073126         0.081334
# 2          0.037951         0.000000         0.032916         0.044307
# 3          0.000000         0.048309         0.032916         0.000000
# 4          0.000000         0.096618         0.164582         0.044307
# ..              ...              ...              ...              ...
# 95         0.453386         0.865801         0.623296         1.040526
# 96         0.752651         0.466200         0.405542         0.971503
# 97         0.034211         0.000000         0.067590         0.064767
# 98         0.335993         0.037509         0.147275         0.068587
# 99         0.000000         0.000000         0.000000         0.034294
#
# [100 rows x 26 columns]

# %%
len(isnv_stat_all['vsname'].drop_duplicates())
# Out:
# 43

# %%
vardirection_mergebaseperc.drop('sn', axis=1).groupby(['vsname','refid']).mean()#.to_excel('iSNV_vdirection_stat_norm_mergevs.xlsx')

# %%
vardirection_mergebaseperc.to_excel('iSNV_vdirection_stat_norm.xlsx', index=None)

# %%
pd.DataFrame(statresult, columns=['vsname', 'num_sample', 'num_iSNV']).sort_values(['num_sample', 'num_iSNV'], ascending=False).reset_index(drop=True)
# Out:
#        vsname  num_sample  num_iSNV
# 0     ParV-1A          17       215
# 1       CV-2C           6        72
# 2      CoV-8A           5       191
# 3     ParV-2A           5        26
# 4      CoV-8B           5         7
# 5      CV-14A           4       102
# 6      CoV-6A           4         9
# 7    PicoV-4B           3        87
# 8      CV-12A           3        23
# 9      CoV-8C           3         2
# 10    ReoV-2B           2        71
# 11  PicoV-11A           2        57
# 12    HanV-1A           2        34
# 13      CV-4A           2        29
# 14      CV-6A           2        25
# 15    CalV-3C           2        24
# 16  PicoV-10A           2        22
# 17   PicoV-6A           2        21
# 18     AdV-2A           2        18
# 19   AstV-15A           2        13
# 20   CalV-11A           2        10
# 21      CV-1A           2         8
# 22   ParV-13A           2         6
# 23     CoV-6B           2         4
# 24    CalV-9B           1        88
# 25   CalV-15A           1        11
# 26   ParV-16B           1         8
# 27  PicoV-19A           1         7
# 28  PicoV-25A           1         7
# 29   PicoV-4A           1         6
# 30      CV-3A           1         5
# 31  PicoV-17A           1         5
# 32   PicoV-8A           1         5
# 33    ReoV-3A           1         5
# 34    AstV-9A           1         4
# 35  PicoV-25C           1         4
# 36     CoV-3A           1         3
# 37   PicoV-4C           1         3
# 38    ParV-7A           1         2
# 39  PicoV-13A           1         2
# 40    PoxV-1A           1         2
# 41    CalV-5A           1         1
# 42   ParV-11A           1         1

# %% [markdown]
# Compare divergent & non-divergent ns-iSNV allele frequency

# %%
isnv_full = pd.read_excel('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/iSNV_full_perPOS_annotated.xlsx')
isnv_stat_filtdp = pd.read_excel('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/iSNV_DPstat_filtCoInf_filtDP_indv.xlsx')
dpdata = isnv_full.merge(isnv_stat_filtdp[['vsname', 'sn']], on=['vsname', 'sn'])
dpdata
dpdata['CHROM_POS'] = dpdata['CHROM'] + '_' + dpdata['POS'].astype(str)
dpdata
# Out:
#                SN     CHROM   POS REF ALT      ADPP          Annotation  \
# 0     R2101013357  CalV-11A  3405   C   T  0.145695  synonymous_variant
# 1     R2101013357  CalV-11A  6156   C   T  0.101266  synonymous_variant
# 2     R2101013357  CalV-11A  6189   C   T  0.070755  synonymous_variant
# 3     R2101013362  CalV-11A   108   C   T  0.071563  synonymous_variant
# 4     R2101013362  CalV-11A  1380   T   C  0.060311  synonymous_variant
# ...           ...       ...   ...  ..  ..       ...                 ...
# 1658  R2101012916     CV-6A  1399   A   G  0.427350    missense_variant
# 1659  R2101012916     CV-6A  1405   A   T  0.356436    missense_variant
# 1660  R2101012916     CV-6A  1814   T   C  0.340659  synonymous_variant
# 1661  R2101012909     CV-6A  1387   C   A  0.160987    missense_variant
# 1662  R2101012909     CV-6A  1387   C   T  0.056404    missense_variant
#
#                sn    vsname      CHROM_POS
# 0     R2101013357  CalV-11A  CalV-11A_3405
# 1     R2101013357  CalV-11A  CalV-11A_6156
# 2     R2101013357  CalV-11A  CalV-11A_6189
# 3     R2101013362  CalV-11A   CalV-11A_108
# 4     R2101013362  CalV-11A  CalV-11A_1380
# ...           ...       ...            ...
# 1658  R2101012916     CV-6A     CV-6A_1399
# 1659  R2101012916     CV-6A     CV-6A_1405
# 1660  R2101012916     CV-6A     CV-6A_1814
# 1661  R2101012909     CV-6A     CV-6A_1387
# 1662  R2101012909     CV-6A     CV-6A_1387
#
# [1663 rows x 10 columns]

# %%
dpdata = dpdata[dpdata['CHROM'].apply(lambda x: x.startswith('CoV-8A'))]

# %%
all_divergent_sites = []
for vsname in ['CoV-8B', 'CoV-8C']:
    msavcf = glob('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/GenomeAnnotation/CoV-8/msa2vcf/CoV-8A_ref{vsprefix}.vcf'.format(vsprefix=vsname.split('-')[-1]))
    divergent_sites = set()
    for vcfpath in msavcf:
        divergent_sites = divergent_sites | set(parsing_sitepos(vcfpath))
    all_divergent_sites += list(map(lambda x: vsname+'_' +str(x), divergent_sites))

# %%
all_divergent_sites
# Out:
# ['CoV-8B_1',
#  'CoV-8B_24577',
#  'CoV-8B_24601',
#  'CoV-8B_24607',
#  'CoV-8B_16425',
#  'CoV-8B_24618',
#  'CoV-8B_8238',
#  'CoV-8B_16431',
#  'CoV-8B_8242',
#  'CoV-8B_24627',
#  'CoV-8B_24630',
#  'CoV-8B_24633',
#  'CoV-8B_24636',
#  'CoV-8B_24639',
#  'CoV-8B_24642',
#  'CoV-8B_8260',
#  'CoV-8B_24645',
#  'CoV-8B_24646',
#  'CoV-8B_24657',
#  'CoV-8B_24660',
#  'CoV-8B_24663',
#  'CoV-8B_89',
#  'CoV-8B_96',
#  'CoV-8B_24678',
#  'CoV-8B_24681',
#  'CoV-8B_24687',
#  'CoV-8B_122',
#  'CoV-8B_24699',
#  'CoV-8B_24700',
#  'CoV-8B_128',
#  'CoV-8B_24709',
#  'CoV-8B_24711',
#  'CoV-8B_24714',
#  'CoV-8B_16527',
#  'CoV-8B_24726',
#  'CoV-8B_155',
#  'CoV-8B_16539',
#  'CoV-8B_24732',
#  'CoV-8B_24733',
#  'CoV-8B_8356',
#  'CoV-8B_8359',
#  'CoV-8B_24744',
#  'CoV-8B_24747',
#  'CoV-8B_24748',
#  'CoV-8B_24750',
#  'CoV-8B_8368',
#  'CoV-8B_24753',
#  'CoV-8B_182',
#  'CoV-8B_24759',
#  'CoV-8B_24765',
#  'CoV-8B_190',
#  'CoV-8B_24768',
#  'CoV-8B_16581',
#  'CoV-8B_16582',
#  'CoV-8B_16584',
#  'CoV-8B_24780',
#  'CoV-8B_24781',
#  'CoV-8B_8398',
#  'CoV-8B_16590',
#  'CoV-8B_24783',
#  'CoV-8B_209',
#  'CoV-8B_16599',
#  'CoV-8B_24792',
#  'CoV-8B_24795',
#  'CoV-8B_221',
#  'CoV-8B_24801',
#  'CoV-8B_24804',
#  'CoV-8B_16617',
#  'CoV-8B_24810',
#  'CoV-8B_16619',
#  'CoV-8B_239',
#  'CoV-8B_24815',
#  'CoV-8B_24819',
#  'CoV-8B_16633',
#  'CoV-8B_24828',
#  'CoV-8B_24835',
#  'CoV-8B_24840',
#  'CoV-8B_24841',
#  'CoV-8B_24843',
#  'CoV-8B_16653',
#  'CoV-8B_24847',
#  'CoV-8B_8464',
#  'CoV-8B_24848',
#  'CoV-8B_24849',
#  'CoV-8B_16662',
#  'CoV-8B_24859',
#  'CoV-8B_24861',
#  'CoV-8B_16671',
#  'CoV-8B_24871',
#  'CoV-8B_24874',
#  'CoV-8B_16683',
#  'CoV-8B_16686',
#  'CoV-8B_16690',
#  'CoV-8B_308',
#  'CoV-8B_8500',
#  'CoV-8B_8501',
#  'CoV-8B_24894',
#  'CoV-8B_8515',
#  'CoV-8B_24901',
#  'CoV-8B_24903',
#  'CoV-8B_24906',
#  'CoV-8B_24909',
#  'CoV-8B_24912',
#  'CoV-8B_340',
#  'CoV-8B_24916',
#  'CoV-8B_24918',
#  'CoV-8B_24919',
#  'CoV-8B_24921',
#  'CoV-8B_24924',
#  'CoV-8B_24925',
#  'CoV-8B_24927',
#  'CoV-8B_24928',
#  'CoV-8B_24929',
#  'CoV-8B_24933',
#  'CoV-8B_24939',
#  'CoV-8B_24942',
#  'CoV-8B_24945',
#  'CoV-8B_8563',
#  'CoV-8B_24948',
#  'CoV-8B_16761',
#  'CoV-8B_24963',
#  'CoV-8B_388',
#  'CoV-8B_24966',
#  'CoV-8B_8584',
#  'CoV-8B_8599',
#  'CoV-8B_24984',
#  'CoV-8B_24988',
#  'CoV-8B_8605',
#  'CoV-8B_24990',
#  'CoV-8B_16806',
#  'CoV-8B_24999',
#  'CoV-8B_16809',
#  'CoV-8B_25002',
#  'CoV-8B_25003',
#  'CoV-8B_25005',
#  'CoV-8B_25008',
#  'CoV-8B_433',
#  'CoV-8B_25011',
#  'CoV-8B_25023',
#  'CoV-8B_25035',
#  'CoV-8B_16846',
#  'CoV-8B_25041',
#  'CoV-8B_8659',
#  'CoV-8B_8662',
#  'CoV-8B_8677',
#  'CoV-8B_25062',
#  'CoV-8B_16875',
#  'CoV-8B_16881',
#  'CoV-8B_25074',
#  'CoV-8B_8692',
#  'CoV-8B_16893',
#  'CoV-8B_511',
#  'CoV-8B_25089',
#  'CoV-8B_517',
#  'CoV-8B_16905',
#  'CoV-8B_25104',
#  'CoV-8B_25110',
#  'CoV-8B_25111',
#  'CoV-8B_25113',
#  'CoV-8B_25114',
#  'CoV-8B_8737',
#  'CoV-8B_25122',
#  'CoV-8B_25125',
#  'CoV-8B_25128',
#  'CoV-8B_25129',
#  'CoV-8B_25138',
#  'CoV-8B_8755',
#  'CoV-8B_25140',
#  'CoV-8B_25143',
#  'CoV-8B_25146',
#  'CoV-8B_571',
#  'CoV-8B_572',
#  'CoV-8B_25152',
#  'CoV-8B_25155',
#  'CoV-8B_16965',
#  'CoV-8B_25164',
#  'CoV-8B_592',
#  'CoV-8B_25173',
#  'CoV-8B_25176',
#  'CoV-8B_17001',
#  'CoV-8B_25194',
#  'CoV-8B_17004',
#  'CoV-8B_25200',
#  'CoV-8B_25203',
#  'CoV-8B_628',
#  'CoV-8B_25206',
#  'CoV-8B_25209',
#  'CoV-8B_17022',
#  'CoV-8B_25221',
#  'CoV-8B_25224',
#  'CoV-8B_25230',
#  'CoV-8B_25236',
#  'CoV-8B_25239',
#  'CoV-8B_671',
#  'CoV-8B_685',
#  'CoV-8B_17070',
#  'CoV-8B_17073',
#  'CoV-8B_17082',
#  'CoV-8B_8893',
#  'CoV-8B_25283',
#  'CoV-8B_718',
#  'CoV-8B_8911',
#  'CoV-8B_25303',
#  'CoV-8B_17113',
#  'CoV-8B_25315',
#  'CoV-8B_745',
#  'CoV-8B_25327',
#  'CoV-8B_25336',
#  'CoV-8B_763',
#  'CoV-8B_25345',
#  'CoV-8B_772',
#  'CoV-8B_25348',
#  'CoV-8B_25351',
#  'CoV-8B_25366',
#  'CoV-8B_25369',
#  'CoV-8B_25372',
#  'CoV-8B_25375',
#  'CoV-8B_25378',
#  'CoV-8B_25381',
#  'CoV-8B_25384',
#  'CoV-8B_25390',
#  'CoV-8B_25393',
#  'CoV-8B_25402',
#  'CoV-8B_829',
#  'CoV-8B_9025',
#  'CoV-8B_25411',
#  'CoV-8B_25413',
#  'CoV-8B_25414',
#  'CoV-8B_9031',
#  'CoV-8B_25417',
#  'CoV-8B_9034',
#  'CoV-8B_25420',
#  'CoV-8B_9037',
#  'CoV-8B_847',
#  'CoV-8B_9040',
#  'CoV-8B_17232',
#  'CoV-8B_850',
#  'CoV-8B_25432',
#  'CoV-8B_17241',
#  'CoV-8B_25435',
#  'CoV-8B_865',
#  'CoV-8B_9058',
#  'CoV-8B_25441',
#  'CoV-8B_868',
#  'CoV-8B_25450',
#  'CoV-8B_25453',
#  'CoV-8B_25471',
#  'CoV-8B_901',
#  'CoV-8B_17286',
#  'CoV-8B_25477',
#  'CoV-8B_25480',
#  'CoV-8B_912',
#  'CoV-8B_25509',
#  'CoV-8B_25518',
#  'CoV-8B_25519',
#  'CoV-8B_25520',
#  'CoV-8B_25526',
#  'CoV-8B_25527',
#  'CoV-8B_9145',
#  'CoV-8B_25530',
#  'CoV-8B_25531',
#  'CoV-8B_25533',
#  'CoV-8B_17343',
#  'CoV-8B_961',
#  'CoV-8B_25537',
#  'CoV-8B_25539',
#  'CoV-8B_25542',
#  'CoV-8B_25551',
#  'CoV-8B_25560',
#  'CoV-8B_25561',
#  'CoV-8B_17370',
#  'CoV-8B_25566',
#  'CoV-8B_25593',
#  'CoV-8B_17406',
#  'CoV-8B_25599',
#  'CoV-8B_25602',
#  'CoV-8B_25605',
#  'CoV-8B_25608',
#  'CoV-8B_25614',
#  'CoV-8B_25617',
#  'CoV-8B_17433',
#  'CoV-8B_25629',
#  'CoV-8B_1054',
#  'CoV-8B_25632',
#  'CoV-8B_25638',
#  'CoV-8B_1076',
#  'CoV-8B_25653',
#  'CoV-8B_25656',
#  'CoV-8B_9274',
#  'CoV-8B_25663',
#  'CoV-8B_25668',
#  'CoV-8B_25671',
#  'CoV-8B_1096',
#  'CoV-8B_1099',
#  'CoV-8B_25686',
#  'CoV-8B_1114',
#  'CoV-8B_25695',
#  'CoV-8B_17505',
#  'CoV-8B_25698',
#  'CoV-8B_25701',
#  'CoV-8B_25707',
#  'CoV-8B_9325',
#  'CoV-8B_17520',
#  'CoV-8B_25713',
#  'CoV-8B_9331',
#  'CoV-8B_25716',
#  'CoV-8B_1141',
#  'CoV-8B_25722',
#  'CoV-8B_25731',
#  'CoV-8B_25734',
#  'CoV-8B_1159',
#  'CoV-8B_25743',
#  'CoV-8B_17553',
#  'CoV-8B_25752',
#  'CoV-8B_17565',
#  'CoV-8B_17589',
#  'CoV-8B_17590',
#  'CoV-8B_1213',
#  'CoV-8B_17602',
#  'CoV-8B_1234',
#  'CoV-8B_1243',
#  'CoV-8B_9445',
#  'CoV-8B_25833',
#  'CoV-8B_1266',
#  'CoV-8B_25848',
#  'CoV-8B_25851',
#  'CoV-8B_25854',
#  'CoV-8B_1285',
#  'CoV-8B_17672',
#  'CoV-8B_1290',
#  'CoV-8B_1291',
#  'CoV-8B_1300',
#  'CoV-8B_9493',
#  'CoV-8B_9496',
#  'CoV-8B_1312',
#  'CoV-8B_25896',
#  'CoV-8B_1330',
#  'CoV-8B_25908',
#  'CoV-8B_17719',
#  'CoV-8B_9535',
#  'CoV-8B_9538',
#  'CoV-8B_1357',
#  'CoV-8B_1378',
#  'CoV-8B_1387',
#  'CoV-8B_26001',
#  'CoV-8B_1428',
#  'CoV-8B_26010',
#  'CoV-8B_26013',
#  'CoV-8B_26014',
#  'CoV-8B_26022',
#  'CoV-8B_17832',
#  'CoV-8B_1459',
#  'CoV-8B_26040',
#  'CoV-8B_1474',
#  'CoV-8B_17871',
#  'CoV-8B_26082',
#  'CoV-8B_26084',
#  'CoV-8B_1510',
#  'CoV-8B_26091',
#  'CoV-8B_1528',
#  'CoV-8B_1540',
#  'CoV-8B_26116',
#  'CoV-8B_26118',
#  'CoV-8B_26121',
#  'CoV-8B_26127',
#  'CoV-8B_1552',
#  'CoV-8B_26130',
#  'CoV-8B_17940',
#  'CoV-8B_1575',
#  'CoV-8B_1579',
#  'CoV-8B_26169',
#  'CoV-8B_1600',
#  'CoV-8B_18009',
#  'CoV-8B_1627',
#  'CoV-8B_18012',
#  'CoV-8B_1634',
#  'CoV-8B_26215',
#  'CoV-8B_26230',
#  'CoV-8B_18045',
#  'CoV-8B_26240',
#  'CoV-8B_26242',
#  'CoV-8B_26246',
#  'CoV-8B_26249',
#  'CoV-8B_26254',
#  'CoV-8B_26260',
#  'CoV-8B_26272',
#  'CoV-8B_26273',
#  'CoV-8B_26275',
#  'CoV-8B_18084',
#  'CoV-8B_18085',
#  'CoV-8B_26282',
#  'CoV-8B_26284',
#  'CoV-8B_26285',
#  'CoV-8B_18096',
#  'CoV-8B_26290',
#  'CoV-8B_26291',
#  'CoV-8B_26296',
#  'CoV-8B_26307',
#  'CoV-8B_26308',
#  'CoV-8B_18120',
#  'CoV-8B_26314',
#  'CoV-8B_1741',
#  'CoV-8B_1742',
#  'CoV-8B_26320',
#  'CoV-8B_26322',
#  'CoV-8B_26323',
#  'CoV-8B_9940',
#  'CoV-8B_18132',
#  'CoV-8B_26329',
#  'CoV-8B_26337',
#  'CoV-8B_26341',
#  'CoV-8B_1768',
#  'CoV-8B_26347',
#  'CoV-8B_26353',
#  'CoV-8B_26356',
#  'CoV-8B_26362',
#  'CoV-8B_26365',
#  'CoV-8B_1796',
#  'CoV-8B_26374',
#  'CoV-8B_26377',
#  'CoV-8B_9995',
#  'CoV-8B_26383',
#  'CoV-8B_26389',
#  'CoV-8B_26392',
#  'CoV-8B_1819',
#  'CoV-8B_26398',
#  'CoV-8B_26407',
#  'CoV-8B_18216',
#  'CoV-8B_26410',
#  'CoV-8B_1837',
#  'CoV-8B_26413',
#  'CoV-8B_26416',
#  'CoV-8B_18225',
#  'CoV-8B_26417',
#  'CoV-8B_26418',
#  'CoV-8B_26419',
#  'CoV-8B_26431',
#  'CoV-8B_1858',
#  'CoV-8B_26434',
#  'CoV-8B_1867',
#  'CoV-8B_1869',
#  'CoV-8B_1872',
#  'CoV-8B_26449',
#  'CoV-8B_18261',
#  'CoV-8B_26461',
#  'CoV-8B_26464',
#  'CoV-8B_26468',
#  'CoV-8B_26469',
#  'CoV-8B_26470',
#  'CoV-8B_26477',
#  'CoV-8B_26479',
#  'CoV-8B_26485',
#  'CoV-8B_1912',
#  'CoV-8B_26491',
#  'CoV-8B_18306',
#  'CoV-8B_18309',
#  'CoV-8B_26503',
#  'CoV-8B_26506',
#  'CoV-8B_26509',
#  'CoV-8B_18330',
#  'CoV-8B_26524',
#  'CoV-8B_26526',
#  'CoV-8B_26527',
#  'CoV-8B_26528',
#  'CoV-8B_26533',
#  'CoV-8B_26534',
#  'CoV-8B_26535',
#  'CoV-8B_26536',
#  'CoV-8B_18345',
#  'CoV-8B_1963',
#  'CoV-8B_26539',
#  'CoV-8B_26542',
#  'CoV-8B_26545',
#  'CoV-8B_26548',
#  'CoV-8B_1975',
#  'CoV-8B_26551',
#  'CoV-8B_1981',
#  'CoV-8B_26557',
#  'CoV-8B_1984',
#  'CoV-8B_26562',
#  'CoV-8B_26563',
#  'CoV-8B_1988',
#  'CoV-8B_26566',
#  'CoV-8B_26567',
#  'CoV-8B_26568',
#  'CoV-8B_10186',
#  'CoV-8B_26572',
#  'CoV-8B_26575',
#  'CoV-8B_26576',
#  'CoV-8B_26577',
#  'CoV-8B_26578',
#  'CoV-8B_26581',
#  'CoV-8B_26582',
#  'CoV-8B_2009',
#  'CoV-8B_26590',
#  'CoV-8B_18399',
#  'CoV-8B_26591',
#  'CoV-8B_26596',
#  'CoV-8B_26597',
#  'CoV-8B_2023',
#  'CoV-8B_18408',
#  'CoV-8B_26603',
#  'CoV-8B_26605',
#  'CoV-8B_26607',
#  'CoV-8B_26609',
#  'CoV-8B_10231',
#  'CoV-8B_10232',
#  'CoV-8B_26620',
#  'CoV-8B_2047',
#  'CoV-8B_2050',
#  'CoV-8B_26626',
#  'CoV-8B_26632',
#  'CoV-8B_2059',
#  'CoV-8B_26638',
#  'CoV-8B_10258',
#  'CoV-8B_26653',
#  'CoV-8B_2083',
#  'CoV-8B_26662',
#  'CoV-8B_26666',
#  'CoV-8B_26667',
#  'CoV-8B_26668',
#  'CoV-8B_26669',
#  'CoV-8B_26672',
#  'CoV-8B_2098',
#  'CoV-8B_26674',
#  'CoV-8B_26675',
#  'CoV-8B_18491',
#  'CoV-8B_10300',
#  'CoV-8B_26683',
#  'CoV-8B_26688',
#  'CoV-8B_2119',
#  'CoV-8B_26695',
#  'CoV-8B_26697',
#  'CoV-8B_26699',
#  'CoV-8B_26701',
#  'CoV-8B_26704',
#  'CoV-8B_26713',
#  'CoV-8B_18522',
#  'CoV-8B_2144',
#  'CoV-8B_26722',
#  'CoV-8B_18534',
#  'CoV-8B_26726',
#  'CoV-8B_26727',
#  'CoV-8B_26728',
#  'CoV-8B_26729',
#  'CoV-8B_26730',
#  'CoV-8B_26732',
#  'CoV-8B_26733',
#  'CoV-8B_26734',
#  'CoV-8B_26738',
#  'CoV-8B_26739',
#  'CoV-8B_26740',
#  'CoV-8B_26742',
#  'CoV-8B_18552',
#  'CoV-8B_26746',
#  'CoV-8B_26747',
#  'CoV-8B_26749',
#  'CoV-8B_2176',
#  'CoV-8B_26761',
#  'CoV-8B_10378',
#  'CoV-8B_26763',
#  'CoV-8B_18576',
#  'CoV-8B_26770',
#  'CoV-8B_2197',
#  'CoV-8B_26775',
#  'CoV-8B_26776',
#  'CoV-8B_18591',
#  'CoV-8B_26783',
#  'CoV-8B_26788',
#  'CoV-8B_26800',
#  'CoV-8B_26801',
#  'CoV-8B_2227',
#  'CoV-8B_2231',
#  'CoV-8B_26808',
#  'CoV-8B_26809',
#  'CoV-8B_2234',
#  'CoV-8B_18618',
#  'CoV-8B_26812',
#  'CoV-8B_2242',
#  'CoV-8B_26821',
#  'CoV-8B_18630',
#  'CoV-8B_26824',
#  'CoV-8B_18636',
#  'CoV-8B_26833',
#  'CoV-8B_18642',
#  'CoV-8B_26836',
#  'CoV-8B_26841',
#  'CoV-8B_10459',
#  'CoV-8B_18651',
#  'CoV-8B_26845',
#  'CoV-8B_10468',
#  'CoV-8B_26854',
#  'CoV-8B_18668',
#  'CoV-8B_18681',
#  'CoV-8B_26878',
#  'CoV-8B_26888',
#  'CoV-8B_18705',
#  'CoV-8B_26900',
#  'CoV-8B_26912',
#  'CoV-8B_26913',
#  'CoV-8B_26914',
#  'CoV-8B_18735',
#  'CoV-8B_26938',
#  'CoV-8B_18747',
#  'CoV-8B_2374',
#  'CoV-8B_2392',
#  'CoV-8B_2393',
#  'CoV-8B_10585',
#  'CoV-8B_2395',
#  'CoV-8B_2396',
#  'CoV-8B_18780',
#  'CoV-8B_18784',
#  'CoV-8B_2410',
#  'CoV-8B_27001',
#  'CoV-8B_27002',
#  'CoV-8B_10628',
#  'CoV-8B_10633',
#  'CoV-8B_2449',
#  'CoV-8B_2452',
#  'CoV-8B_27028',
#  'CoV-8B_2461',
#  'CoV-8B_10666',
#  'CoV-8B_18860',
#  'CoV-8B_10672',
#  'CoV-8B_27081',
#  'CoV-8B_2530',
#  'CoV-8B_27122',
#  'CoV-8B_27124',
#  'CoV-8B_10741',
#  'CoV-8B_18933',
#  'CoV-8B_27127',
#  'CoV-8B_27128',
#  'CoV-8B_27129',
#  'CoV-8B_27130',
#  'CoV-8B_2557',
#  'CoV-8B_2560',
#  'CoV-8B_27142',
#  'CoV-8B_18954',
#  'CoV-8B_27151',
#  'CoV-8B_27154',
#  'CoV-8B_27157',
#  'CoV-8B_27160',
#  'CoV-8B_27161',
#  'CoV-8B_27175',
#  'CoV-8B_27178',
#  'CoV-8B_27181',
#  'CoV-8B_10798',
#  'CoV-8B_27187',
#  'CoV-8B_2612',
#  'CoV-8B_27188',
#  'CoV-8B_27190',
#  'CoV-8B_27193',
#  'CoV-8B_27196',
#  'CoV-8B_10813',
#  'CoV-8B_27205',
#  'CoV-8B_27208',
#  'CoV-8B_19020',
#  'CoV-8B_2638',
#  'CoV-8B_2641',
#  'CoV-8B_19026',
#  'CoV-8B_27223',
#  'CoV-8B_27226',
#  'CoV-8B_27238',
#  'CoV-8B_27250',
#  'CoV-8B_19059',
#  'CoV-8B_19062',
#  'CoV-8B_27259',
#  'CoV-8B_27268',
#  'CoV-8B_27280',
#  'CoV-8B_2707',
#  'CoV-8B_2712',
#  'CoV-8B_2719',
#  'CoV-8B_27295',
#  'CoV-8B_27298',
#  'CoV-8B_27310',
#  'CoV-8B_27312',
#  'CoV-8B_19122',
#  'CoV-8B_27314',
#  'CoV-8B_27315',
#  'CoV-8B_27316',
#  'CoV-8B_27317',
#  'CoV-8B_27319',
#  'CoV-8B_27320',
#  'CoV-8B_27321',
#  'CoV-8B_27326',
#  'CoV-8B_27327',
#  'CoV-8B_2752',
#  'CoV-8B_19137',
#  'CoV-8B_27328',
#  'CoV-8B_27333',
#  'CoV-8B_27337',
#  'CoV-8B_27340',
#  'CoV-8B_27343',
#  'CoV-8B_19155',
#  'CoV-8B_2773',
#  'CoV-8B_27352',
#  'CoV-8B_19173',
#  'CoV-8B_27367',
#  'CoV-8B_19176',
#  'CoV-8B_27368',
#  'CoV-8B_10987',
#  'CoV-8B_27373',
#  'CoV-8B_10990',
#  'CoV-8B_27374',
#  'CoV-8B_27375',
#  'CoV-8B_27376',
#  'CoV-8B_27377',
#  'CoV-8B_27378',
#  'CoV-8B_10996',
#  'CoV-8B_27382',
#  'CoV-8B_2809',
#  'CoV-8B_2810',
#  'CoV-8B_27386',
#  'CoV-8B_27387',
#  'CoV-8B_27388',
#  'CoV-8B_27391',
#  'CoV-8B_27394',
#  'CoV-8B_11012',
#  'CoV-8B_11015',
#  'CoV-8B_27403',
#  'CoV-8B_27409',
#  'CoV-8B_27413',
#  'CoV-8B_27415',
#  'CoV-8B_19224',
#  'CoV-8B_27418',
#  'CoV-8B_27423',
#  'CoV-8B_2851',
#  'CoV-8B_11044',
#  'CoV-8B_27427',
#  'CoV-8B_11047',
#  'CoV-8B_27433',
#  'CoV-8B_27436',
#  'CoV-8B_27442',
#  'CoV-8B_19251',
#  'CoV-8B_11065',
#  'CoV-8B_19257',
#  'CoV-8B_27449',
#  'CoV-8B_19260',
#  'CoV-8B_11074',
#  'CoV-8B_19266',
#  'CoV-8B_27459',
#  'CoV-8B_11080',
#  'CoV-8B_2893',
#  'CoV-8B_2897',
#  'CoV-8B_27473',
#  'CoV-8B_2899',
#  'CoV-8B_11092',
#  'CoV-8B_27476',
#  'CoV-8B_2902',
#  'CoV-8B_27477',
#  'CoV-8B_27478',
#  'CoV-8B_27479',
#  'CoV-8B_27481',
#  'CoV-8B_27484',
#  'CoV-8B_19293',
#  'CoV-8B_27489',
#  'CoV-8B_27496',
#  'CoV-8B_11113',
#  'CoV-8B_2923',
#  'CoV-8B_27499',
#  'CoV-8B_2926',
#  'CoV-8B_27502',
#  'CoV-8B_27503',
#  'CoV-8B_19314',
#  'CoV-8B_27506',
#  'CoV-8B_27508',
#  'CoV-8B_27509',
#  'CoV-8B_27510',
#  'CoV-8B_2935',
#  'CoV-8B_27511',
#  'CoV-8B_27513',
#  'CoV-8B_27514',
#  'CoV-8B_27518',
#  'CoV-8B_2944',
#  'CoV-8B_27520',
#  'CoV-8B_27521',
#  'CoV-8B_27523',
#  'CoV-8B_19335',
#  'CoV-8B_11146',
#  'CoV-8B_19338',
#  'CoV-8B_19339',
#  'CoV-8B_27533',
#  'CoV-8B_27534',
#  'CoV-8B_27535',
#  'CoV-8B_19344',
#  'CoV-8B_27536',
#  'CoV-8B_2962',
#  'CoV-8B_27537',
#  'CoV-8B_27538',
#  'CoV-8B_2965',
#  'CoV-8B_27539',
#  'CoV-8B_27540',
#  'CoV-8B_27541',
#  'CoV-8B_27547',
#  'CoV-8B_27548',
#  'CoV-8B_27549',
#  'CoV-8B_2974',
#  'CoV-8B_27553',
#  'CoV-8B_27560',
#  'CoV-8B_27562',
#  'CoV-8B_27565',
#  'CoV-8B_27567',
#  'CoV-8B_27569',
#  'CoV-8B_27570',
#  'CoV-8B_27571',
#  'CoV-8B_27572',
#  'CoV-8B_3001',
#  'CoV-8B_27577',
#  'CoV-8B_27579',
#  'CoV-8B_11197',
#  'CoV-8B_27584',
#  'CoV-8B_27586',
#  'CoV-8B_27590',
#  'CoV-8B_3016',
#  'CoV-8B_27593',
#  'CoV-8B_27594',
#  'CoV-8B_19407',
#  'CoV-8B_27601',
#  'CoV-8B_27610',
#  'CoV-8B_3040',
#  'CoV-8B_27616',
#  'CoV-8B_11239',
#  'CoV-8B_27636',
#  'CoV-8B_27637',
#  'CoV-8B_11254',
#  'CoV-8B_27640',
#  'CoV-8B_27645',
#  'CoV-8B_27646',
#  'CoV-8B_11263',
#  'CoV-8B_27658',
#  'CoV-8B_11276',
#  'CoV-8B_27664',
#  'CoV-8B_27667',
#  'CoV-8B_27669',
#  'CoV-8B_27670',
#  'CoV-8B_27674',
#  'CoV-8B_3100',
#  'CoV-8B_27677',
#  'CoV-8B_3113',
#  'CoV-8B_11311',
#  'CoV-8B_3127',
#  'CoV-8B_3130',
#  'CoV-8B_27710',
#  'CoV-8B_3139',
#  'CoV-8B_27716',
#  'CoV-8B_11335',
#  'CoV-8B_27720',
#  'CoV-8B_11350',
#  'CoV-8B_19551',
#  'CoV-8B_3175',
#  'CoV-8B_3193',
#  'CoV-8B_3196',
#  'CoV-8B_3201',
#  'CoV-8B_3206',
#  'CoV-8B_27785',
#  'CoV-8B_11404',
#  'CoV-8B_19596',
#  'CoV-8B_11410',
#  'CoV-8B_3220',
#  'CoV-8B_27815',
#  'CoV-8B_27816',
#  'CoV-8B_3241',
#  'CoV-8B_27826',
#  'CoV-8B_27827',
#  'CoV-8B_3259',
#  'CoV-8B_3265',
#  'CoV-8B_11461',
#  'CoV-8B_19653',
#  'CoV-8B_3271',
#  'CoV-8B_3280',
#  'CoV-8B_3281',
#  'CoV-8B_3285',
#  'CoV-8B_3289',
#  'CoV-8B_3291',
#  'CoV-8B_19677',
#  'CoV-8B_19680',
#  'CoV-8B_3298',
#  'CoV-8B_3309',
#  'CoV-8B_27890',
#  'CoV-8B_19704',
#  'CoV-8B_3325',
#  'CoV-8B_3337',
#  'CoV-8B_27918',
#  'CoV-8B_3361',
#  'CoV-8B_27941',
#  'CoV-8B_3367',
#  'CoV-8B_11560',
#  'CoV-8B_3370',
#  'CoV-8B_19755',
#  'CoV-8B_27949',
#  'CoV-8B_27951',
#  'CoV-8B_27952',
#  'CoV-8B_27954',
#  'CoV-8B_27958',
#  'CoV-8B_19767',
#  'CoV-8B_27959',
#  'CoV-8B_19770',
#  'CoV-8B_27967',
#  'CoV-8B_27968',
#  'CoV-8B_3393',
#  'CoV-8B_19777',
#  'CoV-8B_27969',
#  'CoV-8B_27975',
#  'CoV-8B_27976',
#  'CoV-8B_27978',
#  'CoV-8B_27979',
#  'CoV-8B_19788',
#  'CoV-8B_27980',
#  'CoV-8B_27983',
#  'CoV-8B_27985',
#  'CoV-8B_27987',
#  'CoV-8B_27988',
#  'CoV-8B_27989',
#  'CoV-8B_27990',
#  'CoV-8B_27991',
#  'CoV-8B_27992',
#  'CoV-8B_27993',
#  'CoV-8B_27994',
#  'CoV-8B_19803',
#  'CoV-8B_27996',
#  'CoV-8B_27998',
#  'CoV-8B_28000',
#  'CoV-8B_28001',
#  'CoV-8B_28004',
#  'CoV-8B_28005',
#  'CoV-8B_28007',
#  'CoV-8B_28008',
#  'CoV-8B_3433',
#  'CoV-8B_28011',
#  'CoV-8B_28012',
#  'CoV-8B_28013',
#  'CoV-8B_28015',
#  'CoV-8B_28017',
#  'CoV-8B_28019',
#  'CoV-8B_28020',
#  'CoV-8B_28021',
#  'CoV-8B_19830',
#  'CoV-8B_28022',
#  'CoV-8B_28023',
#  'CoV-8B_28024',
#  'CoV-8B_28027',
#  'CoV-8B_28029',
#  'CoV-8B_3454',
#  'CoV-8B_28030',
#  'CoV-8B_28031',
#  'CoV-8B_28032',
#  'CoV-8B_28033',
#  'CoV-8B_28035',
#  'CoV-8B_28036',
#  'CoV-8B_28038',
#  'CoV-8B_28042',
#  'CoV-8B_28043',
#  'CoV-8B_28044',
#  'CoV-8B_28045',
#  'CoV-8B_28048',
#  'CoV-8B_11665',
#  'CoV-8B_28050',
#  'CoV-8B_28051',
#  'CoV-8B_11668',
#  'CoV-8B_28052',
#  'CoV-8B_28054',
#  'CoV-8B_28055',
#  'CoV-8B_28056',
#  'CoV-8B_28057',
#  'CoV-8B_19866',
#  'CoV-8B_28058',
#  'CoV-8B_28059',
#  'CoV-8B_19869',
#  'CoV-8B_28060',
#  'CoV-8B_28062',
#  'CoV-8B_28063',
#  'CoV-8B_28065',
#  'CoV-8B_3491',
#  'CoV-8B_11683',
#  'CoV-8B_19881',
#  'CoV-8B_3502',
#  'CoV-8B_3507',
#  'CoV-8B_11701',
#  'CoV-8B_3511',
#  'CoV-8B_3512',
#  'CoV-8B_3553',
#  'CoV-8B_19938',
#  'CoV-8B_19947',
#  'CoV-8B_3565',
#  'CoV-8B_19953',
#  'CoV-8B_19956',
#  'CoV-8B_3583',
#  'CoV-8B_3586',
#  'CoV-8B_11779',
#  'CoV-8B_19971',
#  'CoV-8B_19980',
#  'CoV-8B_3601',
#  'CoV-8B_19989',
#  'CoV-8B_3611',
#  'CoV-8B_19995',
#  'CoV-8B_20004',
#  'CoV-8B_3622',
#  'CoV-8B_20010',
#  'CoV-8B_20011',
#  'CoV-8B_20013',
#  ...]

# %%
dpdata_cov8 = dpdata[dpdata['CHROM'].isin(['CoV-8A', 'CoV-8B', 'CoV-8C'])]
dpdata_cov8
# Out:
#               SN   CHROM    POS REF ALT      ADPP               Annotation  \
# 153  R2101013201  CoV-8B  27941   C   T  0.192825  downstream_gene_variant
# 154  R2101013287  CoV-8B  27941   C   T  0.137566  downstream_gene_variant
# 155  R2101013338  CoV-8B  27941   C   T  0.100000  downstream_gene_variant
# 156  R2101013288  CoV-8B   8056   G   T  0.205128       synonymous_variant
# 157  R2101013288  CoV-8B  21331   G   T  0.052632       synonymous_variant
# ..           ...     ...    ...  ..  ..       ...                      ...
# 576  R2012012511  CoV-8A  24160   G   C  0.080645         missense_variant
# 577  R2012012511  CoV-8A  24526   G   T  0.051339         missense_variant
# 578  R2012012506  CoV-8A  21288   G   A  0.050633       synonymous_variant
# 579  R2012012506  CoV-8A  22179   T   C  0.101852       synonymous_variant
# 580  R2012012514  CoV-8A  22038   C   A  0.060660       synonymous_variant
#
#               sn  vsname     CHROM_POS
# 153  R2101013201  CoV-8B  CoV-8B_27941
# 154  R2101013287  CoV-8B  CoV-8B_27941
# 155  R2101013338  CoV-8B  CoV-8B_27941
# 156  R2101013288  CoV-8B   CoV-8B_8056
# 157  R2101013288  CoV-8B  CoV-8B_21331
# ..           ...     ...           ...
# 576  R2012012511  CoV-8A  CoV-8A_24160
# 577  R2012012511  CoV-8A  CoV-8A_24526
# 578  R2012012506  CoV-8A  CoV-8A_21288
# 579  R2012012506  CoV-8A  CoV-8A_22179
# 580  R2012012514  CoV-8A  CoV-8A_22038
#
# [73 rows x 10 columns]

# %%
dpdata_cov8['divergent_pos'] = [  True if pos in all_divergent_sites else False for pos in dpdata_cov8['CHROM_POS'] ]
# Out:
# /tmp/ipykernel_3953/1098738744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dpdata_cov8['divergent_pos'] = [  True if pos in all_divergent_sites else False for pos in dpdata_cov8['CHROM_POS'] ]

# %%
dpdata_cov8_nsisnv = dpdata_cov8[dpdata_cov8['Annotation']=='missense_variant']
dpdata_cov8_nsisnv
# Out:
#               SN   CHROM    POS REF ALT      ADPP        Annotation  \
# 159  R2101013288  CoV-8B  27413   A   G  0.093264  missense_variant
# 160  R2101013286  CoV-8B  20896   G   T  0.147541  missense_variant
# 370  R2101013330  CoV-8C  26901   C   T  0.103333  missense_variant
# 372  R2101013333  CoV-8C  26901   C   T  0.111801  missense_variant
# 519  R2012012513  CoV-8A   6574   G   T  0.384615  missense_variant
# 520  R2012012513  CoV-8A  22367   G   T  0.125000  missense_variant
# 521  R2012012513  CoV-8A  22417   T   A  0.111650  missense_variant
# 522  R2012012513  CoV-8A  23423   G   C  0.068729  missense_variant
# 527  R2012012513  CoV-8A  23895   G   T  0.086806  missense_variant
# 533  R2012012513  CoV-8A  23915   G   A  0.176471  missense_variant
# 544  R2012012513  CoV-8A  24003   G   T  0.112583  missense_variant
# 551  R2012012513  CoV-8A  24062   C   T  0.062035  missense_variant
# 553  R2012012513  CoV-8A  24065   A   G  0.062035  missense_variant
# 557  R2012012513  CoV-8A  24084   G   T  0.050526  missense_variant
# 561  R2012012513  CoV-8A  25782   G   T  0.065099  missense_variant
# 562  R2012012513  CoV-8A  26238   C   T  0.115226  missense_variant
# 564  R2012012511  CoV-8A   5238   G   C  0.095541  missense_variant
# 567  R2012012511  CoV-8A  20675   C   T  0.117978  missense_variant
# 570  R2012012511  CoV-8A  21262   C   A  0.110169  missense_variant
# 571  R2012012511  CoV-8A  21502   T   C  0.080000  missense_variant
# 572  R2012012511  CoV-8A  21704   G   T  0.059289  missense_variant
# 575  R2012012511  CoV-8A  23809   G   C  0.091205  missense_variant
# 576  R2012012511  CoV-8A  24160   G   C  0.080645  missense_variant
# 577  R2012012511  CoV-8A  24526   G   T  0.051339  missense_variant
#
#               sn  vsname     CHROM_POS  divergent_pos
# 159  R2101013288  CoV-8B  CoV-8B_27413           True
# 160  R2101013286  CoV-8B  CoV-8B_20896           True
# 370  R2101013330  CoV-8C  CoV-8C_26901           True
# 372  R2101013333  CoV-8C  CoV-8C_26901           True
# 519  R2012012513  CoV-8A   CoV-8A_6574          False
# 520  R2012012513  CoV-8A  CoV-8A_22367          False
# 521  R2012012513  CoV-8A  CoV-8A_22417          False
# 522  R2012012513  CoV-8A  CoV-8A_23423          False
# 527  R2012012513  CoV-8A  CoV-8A_23895          False
# 533  R2012012513  CoV-8A  CoV-8A_23915           True
# 544  R2012012513  CoV-8A  CoV-8A_24003          False
# 551  R2012012513  CoV-8A  CoV-8A_24062           True
# 553  R2012012513  CoV-8A  CoV-8A_24065          False
# 557  R2012012513  CoV-8A  CoV-8A_24084          False
# 561  R2012012513  CoV-8A  CoV-8A_25782          False
# 562  R2012012513  CoV-8A  CoV-8A_26238          False
# 564  R2012012511  CoV-8A   CoV-8A_5238          False
# 567  R2012012511  CoV-8A  CoV-8A_20675          False
# 570  R2012012511  CoV-8A  CoV-8A_21262           True
# 571  R2012012511  CoV-8A  CoV-8A_21502          False
# 572  R2012012511  CoV-8A  CoV-8A_21704          False
# 575  R2012012511  CoV-8A  CoV-8A_23809          False
# 576  R2012012511  CoV-8A  CoV-8A_24160           True
# 577  R2012012511  CoV-8A  CoV-8A_24526           True

# %%
dpdata_cov8.to_excel('DP_divergentPOS_inCoV8.xlsx')
# Out:
#      vsname           sn  num_varsite  synonymous_varnum  synonymous_mean  \
# 153  CoV-8B  R2101013201            2                  0              NaN
# 154  CoV-8B  R2101013287            1                  0              NaN
# 155  CoV-8B  R2101013338            1                  0              NaN
# 156  CoV-8B  R2101013288            4                  3         0.108848
# 157  CoV-8B  R2101013288            4                  3         0.108848
# ..      ...          ...          ...                ...              ...
# 585  CoV-8A  R2012012511           69                  6         0.132715
# 586  CoV-8A  R2012012511           69                  6         0.132715
# 587  CoV-8A  R2012012506           70                  2         0.076242
# 588  CoV-8A  R2012012506           70                  2         0.076242
# 589  CoV-8A  R2012012514            1                  1         0.060660
#
#      nonsynonymous_varnum  nonsynonymous_mean  meandepth  coverage  \
# 153                     0                 NaN    246.305   90.0427
# 154                     0                 NaN    846.018  100.0000
# 155                     0                 NaN    808.070   99.4059
# 156                     1            0.093264    126.705   99.6229
# 157                     1            0.093264    126.705   99.6229
# ..                    ...                 ...        ...       ...
# 585                     8            0.085771    515.167   98.7956
# 586                     8            0.085771    515.167   98.7956
# 587                     0                 NaN    210.208   97.9997
# 588                     0                 NaN    210.208   97.9997
# 589                     0                 NaN   3734.440  100.0000
#
#               SN   CHROM    POS REF ALT      ADPP               Annotation  \
# 153  R2101013201  CoV-8B  27941   C   T  0.192825  downstream_gene_variant
# 154  R2101013287  CoV-8B  27941   C   T  0.137566  downstream_gene_variant
# 155  R2101013338  CoV-8B  27941   C   T  0.100000  downstream_gene_variant
# 156  R2101013288  CoV-8B   8056   G   T  0.205128       synonymous_variant
# 157  R2101013288  CoV-8B  21331   G   T  0.052632       synonymous_variant
# ..           ...     ...    ...  ..  ..       ...                      ...
# 585  R2012012511  CoV-8A  24160   G   C  0.080645         missense_variant
# 586  R2012012511  CoV-8A  24526   G   T  0.051339         missense_variant
# 587  R2012012506  CoV-8A  21288   G   A  0.050633       synonymous_variant
# 588  R2012012506  CoV-8A  22179   T   C  0.101852       synonymous_variant
# 589  R2012012514  CoV-8A  22038   C   A  0.060660       synonymous_variant
#
#         CHROM_POS  divergent_pos
# 153  CoV-8B_27941           True
# 154  CoV-8B_27941           True
# 155  CoV-8B_27941           True
# 156   CoV-8B_8056          False
# 157  CoV-8B_21331           True
# ..            ...            ...
# 585  CoV-8A_24160           True
# 586  CoV-8A_24526           True
# 587  CoV-8A_21288           True
# 588  CoV-8A_22179           True
# 589  CoV-8A_22038           True
#
# [73 rows x 18 columns]

# %% [markdown]
# RAP & VEP region iSNV & cSNV stat

# %%
popgenome_refgenome = pd.read_table('requant_group.tsv', names=['sn', 'vsname', 'refseqid'])[['vsname', 'refseqid']].drop_duplicates()
popgenome_refgenome
# Out:
#         vsname                refseqid
# 0      ParV-7A    QEPC045-k141_1442856
# 1      FlaV-8A  19BR182KID-k141_466676
# 3      AstV-2A        UV32-k141_536798
# 5    PicoV-17B       UGR87-k141_390365
# 6     CalV-11B        BAT2-k141_981229
# ..         ...                     ...
# 792    CalV-3A       BAT272-k141_26345
# 800   PicoV-7A       BAT0740-k141_8863
# 802   ParaV-5A     19BR181KID-k99_6171
# 807    CalV-2A         BAT784-k99_1727
# 811   AstV-16A       BAT255-k141_15655
#
# [251 rows x 2 columns]

# %%
isnvdata = pd.read_excel('/jdfssz1/ST_HEALTH/P20Z10200N0206/renzirui/EA_redo/ViralStrain_PopGenetics/iSNV_DPperPOS_filtered.xlsx')
isnvdata
# Out:
#         vsname           sn  num_varsite  synonymous_varnum  synonymous_mean  \
# 0     CalV-11A  R2101013357            3                  3         0.105905
# 1     CalV-11A  R2101013357            3                  3         0.105905
# 2     CalV-11A  R2101013357            3                  3         0.105905
# 3     CalV-11A  R2101013362            7                  7         0.187506
# 4     CalV-11A  R2101013362            7                  7         0.187506
# ...        ...          ...          ...                ...              ...
# 1776     CV-6A  R2101012916           24                  3         0.306084
# 1777     CV-6A  R2101012916           24                  3         0.306084
# 1778     CV-6A  R2101012916           24                  3         0.306084
# 1779     CV-6A  R2101012909            2                  0              NaN
# 1780     CV-6A  R2101012909            2                  0              NaN
#
#       nonsynonymous_varnum  nonsynonymous_mean  meandepth  coverage  \
# 0                        0                 NaN    322.859     100.0
# 1                        0                 NaN    322.859     100.0
# 2                        0                 NaN    322.859     100.0
# 3                        0                 NaN    628.607     100.0
# 4                        0                 NaN    628.607     100.0
# ...                    ...                 ...        ...       ...
# 1776                     4            0.316236    171.254     100.0
# 1777                     4            0.316236    171.254     100.0
# 1778                     4            0.316236    171.254     100.0
# 1779                     2            0.108696   1086.840     100.0
# 1780                     2            0.108696   1086.840     100.0
#
#                SN     CHROM   POS REF ALT      ADPP          Annotation
# 0     R2101013357  CalV-11A  3405   C   T  0.145695  synonymous_variant
# 1     R2101013357  CalV-11A  6156   C   T  0.101266  synonymous_variant
# 2     R2101013357  CalV-11A  6189   C   T  0.070755  synonymous_variant
# 3     R2101013362  CalV-11A   108   C   T  0.071563  synonymous_variant
# 4     R2101013362  CalV-11A  1380   T   C  0.060311  synonymous_variant
# ...           ...       ...   ...  ..  ..       ...                 ...
# 1776  R2101012916     CV-6A  1399   A   G  0.427350    missense_variant
# 1777  R2101012916     CV-6A  1405   A   T  0.356436    missense_variant
# 1778  R2101012916     CV-6A  1814   T   C  0.340659  synonymous_variant
# 1779  R2101012909     CV-6A  1387   C   A  0.160987    missense_variant
# 1780  R2101012909     CV-6A  1387   C   T  0.056404    missense_variant
#
# [1781 rows x 16 columns]
